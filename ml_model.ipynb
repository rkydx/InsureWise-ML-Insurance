# %% [markdown]
# ### ML Model Generation for Insurance Premium

# %%
# %pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in f:\python313\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in f:\python313\lib\site-packages (from scikit-learn) (2.3.0)
# Requirement already satisfied: scipy>=1.8.0 in f:\python313\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in f:\python313\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in f:\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
import pickle

# %%
df = pd.read_csv('insurance_record.csv')

# %%
df.sample(5)
# Out:
#     age  weight  height  Annual_Income  smoker        city Residency_status  \
# 50   55    66.7    1.88          76381    True    Sengkang               PR
# 31   39    51.1    1.83          35091   False      Pungol          Citizen
# 2    39    56.8    1.64         251935    True  Outrampark               PR
# 76   62    99.1    1.50         258871    True   Pasir Ris               PR
# 98   27   101.1    1.82         213254    True       Bedok        Foreigner
#
#         occupation insurance_premium_category
# 50      freelancer                     Medium
# 31  government_job                        Low
# 2          retired                       High
# 76      freelancer                       High
# 98  business_owner                       High

# %%
df['occupation'].unique()
# Out:
# array(['retired', 'business_owner', 'student', 'freelancer',
#        'government_job', 'private_job', 'unemployed'], dtype=object)

# %%
df_feat = df.copy()

# %%
# 1st Feature Engineering: BMI
df_feat["bmi"] = df_feat["weight"] / (df_feat["height"]**2)

# %%
# Age Group function
def age_group(age):
    if age < 25:
        return "young"
    elif age < 45:
        return "adult"
    elif age < 60:
        return "middle_aged"
    return "senior"

# %%
# 2nd Feature Engineering: AGE_GROUP
df_feat["age_group"] = df_feat["age"].apply(age_group)

# %%
def lifestyle_risk(row):
    if row["smoker"] and row["bmi"] > 30:
        return "high"
    if row["smoker"] or row["bmi"] > 27:
        return "medium"
    else:
        return "low"

# %%
# 3rd Feature Engineering: LIFESTYLE_RISK
# axis=1 = row-wise (go across columns within the same row).
df_feat["lifestyle_risk"] = df_feat.apply(lifestyle_risk, axis=1)

# %%
def income_to_bucket(income):
    if pd.isna(income):
        return "unknown"
    if income < 50000:
        return "low"
    if income < 180000:
        return "medium"
    if income < 300000:
        return "high"
    else:
        return "very_high"

# %%
# 4th Feature Engineering: INCOME_BUCKET
df_feat["income_bucket"] = df_feat["Annual_Income"].apply(income_to_bucket)

# %%
df_feat.sample(5)
# Out:
#     age  weight  height  Annual_Income  smoker             city  \
# 23   35    70.3    1.78          85569    True        Pasir Ris
# 35   59    59.3    1.69         140455    True  Holland Village
# 58   72    95.9    1.79         233886    True       Outrampark
# 57   72    76.8    1.69         141330    True            Bugis
# 55   47    75.7    1.73          20174   False          Boonlay
#
#    Residency_status  occupation insurance_premium_category        bmi  \
# 23               PR  freelancer                     Medium  22.187855
# 35          Citizen     student                     Medium  20.762578
# 58        Foreigner  freelancer                       High  29.930402
# 57               PR     student                     Medium  26.889815
# 55          Citizen  unemployed                        Low  25.293194
#
#       age_group lifestyle_risk income_bucket
# 23        adult         medium        medium
# 35  middle_aged         medium        medium
# 58       senior         medium          high
# 57       senior         medium        medium
# 55  middle_aged            low           low

# %%
# Drop raw columns we don't want to use directly
#df_feat = df_feat.drop(columns=['age', 'weight', 'height', 'smoker', 'Annual_Income'])
df_feat = df_feat.drop(columns=['age', 'weight', 'height', 'smoker','Annual_Income'])

# Preview the engineered features + target
df_feat.sample(5)
# Out:
#                city Residency_status      occupation  \
# 47  Holland Village          Citizen  government_job
# 91    Harbour Front        Foreigner         retired
# 90        Serangoon          Citizen  government_job
# 75         Woodland               PR  business_owner
# 5         Payalebar          Citizen      freelancer
#
#    insurance_premium_category        bmi    age_group lifestyle_risk  \
# 47                        Low  33.286625  middle_aged         medium
# 91                       High  38.675103        adult           high
# 90                        Low  21.093750  middle_aged            low
# 75                       High  20.577355  middle_aged         medium
# 5                      Medium  22.826245  middle_aged            low
#
#    income_bucket
# 47        medium
# 91          high
# 90           low
# 75     very_high
# 5         medium

# %%
# Select features and target
X = df_feat[["bmi", "age_group", "lifestyle_risk", "city", "Residency_status", "occupation", "income_bucket"]]
y = df_feat["insurance_premium_category"]

# %%
X
# Out:
#            bmi    age_group lifestyle_risk        city Residency_status  \
# 0    49.227482       senior           high    Sengkang               PR
# 1    30.189017        adult           high    Tampines        Foreigner
# 2    21.118382        adult         medium  Outrampark               PR
# 3    45.535900        young           high   Serangoon          Citizen
# 4    24.296875       senior         medium  Outrampark        Foreigner
# ..         ...          ...            ...         ...              ...
# 105  32.800735  middle_aged           high   Payalebar          Citizen
# 106  21.860828        adult            low     Boonlay          Citizen
# 107  27.767889       senior         medium     Redhill               PR
# 108  31.176471  middle_aged           high     Boonlay          Citizen
# 109  24.969136  middle_aged            low   Payalebar          Citizen
#
#          occupation income_bucket
# 0           retired          high
# 1    business_owner          high
# 2           retired          high
# 3           student        medium
# 4           retired          high
# ..              ...           ...
# 105      freelancer        medium
# 106         retired           low
# 107         student        medium
# 108         student        medium
# 109      freelancer        medium
#
# [110 rows x 7 columns]

# %%
y
# Out:
# 0        High
# 1        High
# 2        High
# 3      Medium
# 4        High
#         ...
# 105    Medium
# 106       Low
# 107    Medium
# 108    Medium
# 109    Medium
# Name: insurance_premium_category, Length: 110, dtype: object

# %%
# Define categorical and numerical features
cat_features = ["age_group", "lifestyle_risk", "Residency_status", "occupation"]
# num_features = ["bmi", "Annual_Income"]
num_features = ["bmi"]

# %%
# Create column transformer for OneHotEncoding (OHE)
preprocessor = ColumnTransformer(
    transformers = [
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_features),
        ("num", "passthrough", num_features)
    ]
)

# %%
# Create a pipeline with preprocessing and random forest classifier
pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("classifier", RandomForestClassifier(random_state=42))
])

# %%
df_feat.sample(5)
# Out:
#                city Residency_status      occupation  \
# 28        Serangoon          Citizen         retired
# 54           Pungol          Citizen         student
# 8   Holland Village               PR      freelancer
# 21            Bugis        Foreigner         retired
# 98            Bedok        Foreigner  business_owner
#
#    insurance_premium_category        bmi age_group lifestyle_risk  \
# 28                        Low  31.584532     adult         medium
# 54                     Medium  21.025423    senior         medium
# 8                      Medium  23.233456    senior         medium
# 21                       High  27.380671    senior         medium
# 98                       High  30.521676     adult           high
#
#    income_bucket
# 28           low
# 54        medium
# 8         medium
# 21          high
# 98          high

# %%
# Split data and train model
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['age_group',
#                                                    'lifestyle_risk',
#                                                    'Residency_status',
#                                                    'occupation']),
#                                                  ('num', 'passthrough',
#                                                   ['bmi'])])),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %%
# Predict and evaluate by checking the accuracy score
y_pred = pipeline.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9090909090909091

# %%
X_test.sample(5)
# Out:
#           bmi    age_group lifestyle_risk       city Residency_status  \
# 81  31.866055        adult           high  Pasir Ris               PR
# 69  21.942857  middle_aged         medium     Pungol               PR
# 89  30.458274        young           high   Tampines               PR
# 88  31.443698  middle_aged           high  Serangoon               PR
# 17  31.176471       senior           high    Boonlay               PR
#
#         occupation income_bucket
# 81      freelancer          high
# 69      freelancer          high
# 89         retired          high
# 88  business_owner          high
# 17      freelancer        medium

# %%
# Save the trained pipeline using pickle
pickle_model_path = "insurancemodel.pkl"
with open(pickle_model_path, "wb") as f:
    pickle.dump(pipeline,f)
